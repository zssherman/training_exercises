# %% [markdown]
#                                                 Exercise 1
#                                                Zach Sherman
#                                         Argonne National Laboratory

# %%
#Plotting and reading in tabular data with Python.
#Import modules
import pyart
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import scipy
# %matplotlib inline
from datetime import datetime, timedelta
from io import StringIO
from pytz import timezone
from jdcal import gcal2jd, jd2gcal
import matplotlib.dates as mdates
import datetime as dt
print("pyart.__version__")
# Out:
# pyart.__version__
# /home/zsherman/anaconda3/lib/python3.5/site-packages/pyart/map/grid_mapper.py:40: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   from .ball_tree import BallTree
# /home/zsherman/anaconda3/lib/python3.5/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/zsherman/anaconda3/lib/python3.5/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/zsherman/anaconda3/lib/python3.5/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/zsherman/anaconda3/lib/python3.5/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/zsherman/anaconda3/lib/python3.5/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/zsherman/anaconda3/lib/python3.5/site-packages/ipykernel/pylab/config.py:44: DeprecationWarning: InlineBackend._config_changed is deprecated: use @observe and @unobserve instead.
#   def _config_changed(self, name, old, new):
# /home/zsherman/anaconda3/lib/python3.5/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/zsherman/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/zsherman/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/zsherman/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/zsherman/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/zsherman/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/zsherman/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
#Testing in pyart is running correctly.
if pyart.__version__ == "1.6.0":
    if hasattr(pyart.graph, 'RadarMapDisplay'):
        print ("Ready to go")
    else:
        print ("ISSUES\n\nMissing\Broken Basemap\n")
        pyart._debug_info()
else:
    print ("ISSUES\n\nWrong Py-ART version\n")
    pyart._debug_info()
# Out:
# Ready to go

# %%
#Import data via urllib.request.
import urllib.request
radar = urllib.request.Request('http://www.atmos.anl.gov/ANLMET/anltower.48')
data = urllib.request.urlopen(radar) 
my_data = np.recfromtxt(data, skip_header = 2)

# %%
#Defining columns used for plotting.
#Placing data into an array and coverting to float.
Tdp_10m = np.array(my_data[0:192,9])
Tdp_10m = Tdp_10m.astype(np.float64)
Tdp_10m_max = np.amax(Tdp_10m)
Tdp_10m_min = np.amin(Tdp_10m)

# %%
TaC_10m = np.array(my_data[0:192,10])
TaC_10m = TaC_10m.astype(np.float)
TaC_10m_max = np.amax(TaC_10m)
TaC_10m_min = np.amin(TaC_10m)

# %%
julian_date = np.array(my_data[0:192,0])
julian_date = julian_date.astype(np.float)

# %%
time = np.array(my_data[0:192,1])

# %%
#Column stacking time and julian date in order to convert to datetime.
jda_time = np.column_stack((julian_date,time))
jda_time
# Out:
# /home/zsherman/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/zsherman/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# array([[b'279.0', b'09:15'],
#        [b'279.0', b'09:30'],
#        [b'279.0', b'09:45'],
#        [b'279.0', b'10:00'],
#        [b'279.0', b'10:15'],
#        [b'279.0', b'10:30'],
#        [b'279.0', b'10:45'],
#        [b'279.0', b'11:00'],
#        [b'279.0', b'11:15'],
#        [b'279.0', b'11:30'],
#        [b'279.0', b'11:45'],
#        [b'279.0', b'12:00'],
#        [b'279.0', b'12:15'],
#        [b'279.0', b'12:30'],
#        [b'279.0', b'12:45'],
#        [b'279.0', b'13:00'],
#        [b'279.0', b'13:15'],
#        [b'279.0', b'13:30'],
#        [b'279.0', b'13:45'],
#        [b'279.0', b'14:00'],
#        [b'279.0', b'14:15'],
#        [b'279.0', b'14:30'],
#        [b'279.0', b'14:45'],
#        [b'279.0', b'15:00'],
#        [b'279.0', b'15:15'],
#        [b'279.0', b'15:30'],
#        [b'279.0', b'15:45'],
#        [b'279.0', b'16:00'],
#        [b'279.0', b'16:15'],
#        [b'279.0', b'16:30'],
#        [b'279.0', b'16:45'],
#        [b'279.0', b'17:00'],
#        [b'279.0', b'17:15'],
#        [b'279.0', b'17:30'],
#        [b'279.0', b'17:45'],
#        [b'279.0', b'18:00'],
#        [b'279.0', b'18:15'],
#        [b'279.0', b'18:30'],
#        [b'279.0', b'18:45'],
#        [b'279.0', b'19:00'],
#        [b'279.0', b'19:15'],
#        [b'279.0', b'19:30'],
#        [b'279.0', b'19:45'],
#        [b'279.0', b'20:00'],
#        [b'279.0', b'20:15'],
#        [b'279.0', b'20:30'],
#        [b'279.0', b'20:45'],
#        [b'279.0', b'21:00'],
#        [b'279.0', b'21:15'],
#        [b'279.0', b'21:30'],
#        [b'279.0', b'21:45'],
#        [b'279.0', b'22:00'],
#        [b'279.0', b'22:15'],
#        [b'279.0', b'22:30'],
#        [b'279.0', b'22:45'],
#        [b'279.0', b'23:00'],
#        [b'279.0', b'23:15'],
#        [b'279.0', b'23:30'],
#        [b'279.0', b'23:45'],
#        [b'280.0', b'00:00'],
#        [b'280.0', b'00:15'],
#        [b'280.0', b'00:30'],
#        [b'280.0', b'00:45'],
#        [b'280.0', b'01:00'],
#        [b'280.0', b'01:15'],
#        [b'280.0', b'01:30'],
#        [b'280.0', b'01:45'],
#        [b'280.0', b'02:00'],
#        [b'280.0', b'02:15'],
#        [b'280.0', b'02:30'],
#        [b'280.0', b'02:45'],
#        [b'280.0', b'03:00'],
#        [b'280.0', b'03:15'],
#        [b'280.0', b'03:30'],
#        [b'280.0', b'03:45'],
#        [b'280.0', b'04:00'],
#        [b'280.0', b'04:15'],
#        [b'280.0', b'04:30'],
#        [b'280.0', b'04:45'],
#        [b'280.0', b'05:00'],
#        [b'280.0', b'05:15'],
#        [b'280.0', b'05:30'],
#        [b'280.0', b'05:45'],
#        [b'280.0', b'06:00'],
#        [b'280.0', b'06:15'],
#        [b'280.0', b'06:30'],
#        [b'280.0', b'06:45'],
#        [b'280.0', b'07:00'],
#        [b'280.0', b'07:15'],
#        [b'280.0', b'07:30'],
#        [b'280.0', b'07:45'],
#        [b'280.0', b'08:00'],
#        [b'280.0', b'08:15'],
#        [b'280.0', b'08:30'],
#        [b'280.0', b'08:45'],
#        [b'280.0', b'09:00'],
#        [b'280.0', b'09:15'],
#        [b'280.0', b'09:30'],
#        [b'280.0', b'09:45'],
#        [b'280.0', b'10:00'],
#        [b'280.0', b'10:15'],
#        [b'280.0', b'10:30'],
#        [b'280.0', b'10:45'],
#        [b'280.0', b'11:00'],
#        [b'280.0', b'11:15'],
#        [b'280.0', b'11:30'],
#        [b'280.0', b'11:45'],
#        [b'280.0', b'12:00'],
#        [b'280.0', b'12:15'],
#        [b'280.0', b'12:30'],
#        [b'280.0', b'12:45'],
#        [b'280.0', b'13:00'],
#        [b'280.0', b'13:15'],
#        [b'280.0', b'13:30'],
#        [b'280.0', b'13:45'],
#        [b'280.0', b'14:00'],
#        [b'280.0', b'14:15'],
#        [b'280.0', b'14:30'],
#        [b'280.0', b'14:45'],
#        [b'280.0', b'15:00'],
#        [b'280.0', b'15:15'],
#        [b'280.0', b'15:30'],
#        [b'280.0', b'15:45'],
#        [b'280.0', b'16:00'],
#        [b'280.0', b'16:15'],
#        [b'280.0', b'16:30'],
#        [b'280.0', b'16:45'],
#        [b'280.0', b'17:00'],
#        [b'280.0', b'17:15'],
#        [b'280.0', b'17:30'],
#        [b'280.0', b'17:45'],
#        [b'280.0', b'18:00'],
#        [b'280.0', b'18:15'],
#        [b'280.0', b'18:30'],
#        [b'280.0', b'18:45'],
#        [b'280.0', b'19:00'],
#        [b'280.0', b'19:15'],
#        [b'280.0', b'19:30'],
#        [b'280.0', b'19:45'],
#        [b'280.0', b'20:00'],
#        [b'280.0', b'20:15'],
#        [b'280.0', b'20:30'],
#        [b'280.0', b'20:45'],
#        [b'280.0', b'21:00'],
#        [b'280.0', b'21:15'],
#        [b'280.0', b'21:30'],
#        [b'280.0', b'21:45'],
#        [b'280.0', b'22:00'],
#        [b'280.0', b'22:15'],
#        [b'280.0', b'22:30'],
#        [b'280.0', b'22:45'],
#        [b'280.0', b'23:00'],
#        [b'280.0', b'23:15'],
#        [b'280.0', b'23:30'],
#        [b'280.0', b'23:45'],
#        [b'281.0', b'00:00'],
#        [b'281.0', b'00:15'],
#        [b'281.0', b'00:30'],
#        [b'281.0', b'00:45'],
#        [b'281.0', b'01:00'],
#        [b'281.0', b'01:15'],
#        [b'281.0', b'01:30'],
#        [b'281.0', b'01:45'],
#        [b'281.0', b'02:00'],
#        [b'281.0', b'02:15'],
#        [b'281.0', b'02:30'],
#        [b'281.0', b'02:45'],
#        [b'281.0', b'03:00'],
#        [b'281.0', b'03:15'],
#        [b'281.0', b'03:30'],
#        [b'281.0', b'03:45'],
#        [b'281.0', b'04:00'],
#        [b'281.0', b'04:15'],
#        [b'281.0', b'04:30'],
#        [b'281.0', b'04:45'],
#        [b'281.0', b'05:00'],
#        [b'281.0', b'05:15'],
#        [b'281.0', b'05:30'],
#        [b'281.0', b'05:45'],
#        [b'281.0', b'06:00'],
#        [b'281.0', b'06:15'],
#        [b'281.0', b'06:30'],
#        [b'281.0', b'06:45'],
#        [b'281.0', b'07:00'],
#        [b'281.0', b'07:15'],
#        [b'281.0', b'07:30'],
#        [b'281.0', b'07:45'],
#        [b'281.0', b'08:00'],
#        [b'281.0', b'08:15'],
#        [b'281.0', b'08:30'],
#        [b'281.0', b'08:45'],
#        [b'281.0', b'09:00']],
#       dtype='|S32')

# %%
#Creating a datetime object using a for loop.
jda_time = (jda_time)
base = datetime(2016, 1, 1, 0, 0, 0, 0)
transformed = [base + timedelta(days=int(float(x)-1), hours=int(y[0:2]), 
                                minutes=int(y[3:5])) for x, y in jda_time]
datetime_array = np.array(transformed)
datetime_array
# Out:
# array([datetime.datetime(2016, 10, 5, 9, 15),
#        datetime.datetime(2016, 10, 5, 9, 30),
#        datetime.datetime(2016, 10, 5, 9, 45),
#        datetime.datetime(2016, 10, 5, 10, 0),
#        datetime.datetime(2016, 10, 5, 10, 15),
#        datetime.datetime(2016, 10, 5, 10, 30),
#        datetime.datetime(2016, 10, 5, 10, 45),
#        datetime.datetime(2016, 10, 5, 11, 0),
#        datetime.datetime(2016, 10, 5, 11, 15),
#        datetime.datetime(2016, 10, 5, 11, 30),
#        datetime.datetime(2016, 10, 5, 11, 45),
#        datetime.datetime(2016, 10, 5, 12, 0),
#        datetime.datetime(2016, 10, 5, 12, 15),
#        datetime.datetime(2016, 10, 5, 12, 30),
#        datetime.datetime(2016, 10, 5, 12, 45),
#        datetime.datetime(2016, 10, 5, 13, 0),
#        datetime.datetime(2016, 10, 5, 13, 15),
#        datetime.datetime(2016, 10, 5, 13, 30),
#        datetime.datetime(2016, 10, 5, 13, 45),
#        datetime.datetime(2016, 10, 5, 14, 0),
#        datetime.datetime(2016, 10, 5, 14, 15),
#        datetime.datetime(2016, 10, 5, 14, 30),
#        datetime.datetime(2016, 10, 5, 14, 45),
#        datetime.datetime(2016, 10, 5, 15, 0),
#        datetime.datetime(2016, 10, 5, 15, 15),
#        datetime.datetime(2016, 10, 5, 15, 30),
#        datetime.datetime(2016, 10, 5, 15, 45),
#        datetime.datetime(2016, 10, 5, 16, 0),
#        datetime.datetime(2016, 10, 5, 16, 15),
#        datetime.datetime(2016, 10, 5, 16, 30),
#        datetime.datetime(2016, 10, 5, 16, 45),
#        datetime.datetime(2016, 10, 5, 17, 0),
#        datetime.datetime(2016, 10, 5, 17, 15),
#        datetime.datetime(2016, 10, 5, 17, 30),
#        datetime.datetime(2016, 10, 5, 17, 45),
#        datetime.datetime(2016, 10, 5, 18, 0),
#        datetime.datetime(2016, 10, 5, 18, 15),
#        datetime.datetime(2016, 10, 5, 18, 30),
#        datetime.datetime(2016, 10, 5, 18, 45),
#        datetime.datetime(2016, 10, 5, 19, 0),
#        datetime.datetime(2016, 10, 5, 19, 15),
#        datetime.datetime(2016, 10, 5, 19, 30),
#        datetime.datetime(2016, 10, 5, 19, 45),
#        datetime.datetime(2016, 10, 5, 20, 0),
#        datetime.datetime(2016, 10, 5, 20, 15),
#        datetime.datetime(2016, 10, 5, 20, 30),
#        datetime.datetime(2016, 10, 5, 20, 45),
#        datetime.datetime(2016, 10, 5, 21, 0),
#        datetime.datetime(2016, 10, 5, 21, 15),
#        datetime.datetime(2016, 10, 5, 21, 30),
#        datetime.datetime(2016, 10, 5, 21, 45),
#        datetime.datetime(2016, 10, 5, 22, 0),
#        datetime.datetime(2016, 10, 5, 22, 15),
#        datetime.datetime(2016, 10, 5, 22, 30),
#        datetime.datetime(2016, 10, 5, 22, 45),
#        datetime.datetime(2016, 10, 5, 23, 0),
#        datetime.datetime(2016, 10, 5, 23, 15),
#        datetime.datetime(2016, 10, 5, 23, 30),
#        datetime.datetime(2016, 10, 5, 23, 45),
#        datetime.datetime(2016, 10, 6, 0, 0),
#        datetime.datetime(2016, 10, 6, 0, 15),
#        datetime.datetime(2016, 10, 6, 0, 30),
#        datetime.datetime(2016, 10, 6, 0, 45),
#        datetime.datetime(2016, 10, 6, 1, 0),
#        datetime.datetime(2016, 10, 6, 1, 15),
#        datetime.datetime(2016, 10, 6, 1, 30),
#        datetime.datetime(2016, 10, 6, 1, 45),
#        datetime.datetime(2016, 10, 6, 2, 0),
#        datetime.datetime(2016, 10, 6, 2, 15),
#        datetime.datetime(2016, 10, 6, 2, 30),
#        datetime.datetime(2016, 10, 6, 2, 45),
#        datetime.datetime(2016, 10, 6, 3, 0),
#        datetime.datetime(2016, 10, 6, 3, 15),
#        datetime.datetime(2016, 10, 6, 3, 30),
#        datetime.datetime(2016, 10, 6, 3, 45),
#        datetime.datetime(2016, 10, 6, 4, 0),
#        datetime.datetime(2016, 10, 6, 4, 15),
#        datetime.datetime(2016, 10, 6, 4, 30),
#        datetime.datetime(2016, 10, 6, 4, 45),
#        datetime.datetime(2016, 10, 6, 5, 0),
#        datetime.datetime(2016, 10, 6, 5, 15),
#        datetime.datetime(2016, 10, 6, 5, 30),
#        datetime.datetime(2016, 10, 6, 5, 45),
#        datetime.datetime(2016, 10, 6, 6, 0),
#        datetime.datetime(2016, 10, 6, 6, 15),
#        datetime.datetime(2016, 10, 6, 6, 30),
#        datetime.datetime(2016, 10, 6, 6, 45),
#        datetime.datetime(2016, 10, 6, 7, 0),
#        datetime.datetime(2016, 10, 6, 7, 15),
#        datetime.datetime(2016, 10, 6, 7, 30),
#        datetime.datetime(2016, 10, 6, 7, 45),
#        datetime.datetime(2016, 10, 6, 8, 0),
#        datetime.datetime(2016, 10, 6, 8, 15),
#        datetime.datetime(2016, 10, 6, 8, 30),
#        datetime.datetime(2016, 10, 6, 8, 45),
#        datetime.datetime(2016, 10, 6, 9, 0),
#        datetime.datetime(2016, 10, 6, 9, 15),
#        datetime.datetime(2016, 10, 6, 9, 30),
#        datetime.datetime(2016, 10, 6, 9, 45),
#        datetime.datetime(2016, 10, 6, 10, 0),
#        datetime.datetime(2016, 10, 6, 10, 15),
#        datetime.datetime(2016, 10, 6, 10, 30),
#        datetime.datetime(2016, 10, 6, 10, 45),
#        datetime.datetime(2016, 10, 6, 11, 0),
#        datetime.datetime(2016, 10, 6, 11, 15),
#        datetime.datetime(2016, 10, 6, 11, 30),
#        datetime.datetime(2016, 10, 6, 11, 45),
#        datetime.datetime(2016, 10, 6, 12, 0),
#        datetime.datetime(2016, 10, 6, 12, 15),
#        datetime.datetime(2016, 10, 6, 12, 30),
#        datetime.datetime(2016, 10, 6, 12, 45),
#        datetime.datetime(2016, 10, 6, 13, 0),
#        datetime.datetime(2016, 10, 6, 13, 15),
#        datetime.datetime(2016, 10, 6, 13, 30),
#        datetime.datetime(2016, 10, 6, 13, 45),
#        datetime.datetime(2016, 10, 6, 14, 0),
#        datetime.datetime(2016, 10, 6, 14, 15),
#        datetime.datetime(2016, 10, 6, 14, 30),
#        datetime.datetime(2016, 10, 6, 14, 45),
#        datetime.datetime(2016, 10, 6, 15, 0),
#        datetime.datetime(2016, 10, 6, 15, 15),
#        datetime.datetime(2016, 10, 6, 15, 30),
#        datetime.datetime(2016, 10, 6, 15, 45),
#        datetime.datetime(2016, 10, 6, 16, 0),
#        datetime.datetime(2016, 10, 6, 16, 15),
#        datetime.datetime(2016, 10, 6, 16, 30),
#        datetime.datetime(2016, 10, 6, 16, 45),
#        datetime.datetime(2016, 10, 6, 17, 0),
#        datetime.datetime(2016, 10, 6, 17, 15),
#        datetime.datetime(2016, 10, 6, 17, 30),
#        datetime.datetime(2016, 10, 6, 17, 45),
#        datetime.datetime(2016, 10, 6, 18, 0),
#        datetime.datetime(2016, 10, 6, 18, 15),
#        datetime.datetime(2016, 10, 6, 18, 30),
#        datetime.datetime(2016, 10, 6, 18, 45),
#        datetime.datetime(2016, 10, 6, 19, 0),
#        datetime.datetime(2016, 10, 6, 19, 15),
#        datetime.datetime(2016, 10, 6, 19, 30),
#        datetime.datetime(2016, 10, 6, 19, 45),
#        datetime.datetime(2016, 10, 6, 20, 0),
#        datetime.datetime(2016, 10, 6, 20, 15),
#        datetime.datetime(2016, 10, 6, 20, 30),
#        datetime.datetime(2016, 10, 6, 20, 45),
#        datetime.datetime(2016, 10, 6, 21, 0),
#        datetime.datetime(2016, 10, 6, 21, 15),
#        datetime.datetime(2016, 10, 6, 21, 30),
#        datetime.datetime(2016, 10, 6, 21, 45),
#        datetime.datetime(2016, 10, 6, 22, 0),
#        datetime.datetime(2016, 10, 6, 22, 15),
#        datetime.datetime(2016, 10, 6, 22, 30),
#        datetime.datetime(2016, 10, 6, 22, 45),
#        datetime.datetime(2016, 10, 6, 23, 0),
#        datetime.datetime(2016, 10, 6, 23, 15),
#        datetime.datetime(2016, 10, 6, 23, 30),
#        datetime.datetime(2016, 10, 6, 23, 45),
#        datetime.datetime(2016, 10, 7, 0, 0),
#        datetime.datetime(2016, 10, 7, 0, 15),
#        datetime.datetime(2016, 10, 7, 0, 30),
#        datetime.datetime(2016, 10, 7, 0, 45),
#        datetime.datetime(2016, 10, 7, 1, 0),
#        datetime.datetime(2016, 10, 7, 1, 15),
#        datetime.datetime(2016, 10, 7, 1, 30),
#        datetime.datetime(2016, 10, 7, 1, 45),
#        datetime.datetime(2016, 10, 7, 2, 0),
#        datetime.datetime(2016, 10, 7, 2, 15),
#        datetime.datetime(2016, 10, 7, 2, 30),
#        datetime.datetime(2016, 10, 7, 2, 45),
#        datetime.datetime(2016, 10, 7, 3, 0),
#        datetime.datetime(2016, 10, 7, 3, 15),
#        datetime.datetime(2016, 10, 7, 3, 30),
#        datetime.datetime(2016, 10, 7, 3, 45),
#        datetime.datetime(2016, 10, 7, 4, 0),
#        datetime.datetime(2016, 10, 7, 4, 15),
#        datetime.datetime(2016, 10, 7, 4, 30),
#        datetime.datetime(2016, 10, 7, 4, 45),
#        datetime.datetime(2016, 10, 7, 5, 0),
#        datetime.datetime(2016, 10, 7, 5, 15),
#        datetime.datetime(2016, 10, 7, 5, 30),
#        datetime.datetime(2016, 10, 7, 5, 45),
#        datetime.datetime(2016, 10, 7, 6, 0),
#        datetime.datetime(2016, 10, 7, 6, 15),
#        datetime.datetime(2016, 10, 7, 6, 30),
#        datetime.datetime(2016, 10, 7, 6, 45),
#        datetime.datetime(2016, 10, 7, 7, 0),
#        datetime.datetime(2016, 10, 7, 7, 15),
#        datetime.datetime(2016, 10, 7, 7, 30),
#        datetime.datetime(2016, 10, 7, 7, 45),
#        datetime.datetime(2016, 10, 7, 8, 0),
#        datetime.datetime(2016, 10, 7, 8, 15),
#        datetime.datetime(2016, 10, 7, 8, 30),
#        datetime.datetime(2016, 10, 7, 8, 45),
#        datetime.datetime(2016, 10, 7, 9, 0)], dtype=object)

# %%
#Plot dew-point and dry-bulb over cell number.
fig, ax1 = plt.subplots()
fig.suptitle('Dew-point and Dry-bulb Over Cell Number', fontsize=10, fontweight='bold')
y1 = Tdp_10m
ax1.plot(y1, 'b-')
ax1.set_xlabel('Cell Number')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('Dew-point Temperature °C', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim((-0,35))
x = np.arange(0, 192)

ax2 = ax1.twinx()
y2 = TaC_10m
ax2.plot(y2, 'r-')
ax2.set_ylabel('Dry-bulb Temperature °C', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.ylim((-20, 30))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-274428de27ad> in <module>()
#      13
#      14 y2 = TaC_10m
# ---> 15 ax2.plot(y2, 'r-')
#      16 ax2.set_ylabel('Dry-bulb Temperature °C', color='r')
#      17 for tl in ax2.get_yticklabels():
#
# NameError: name 'ax2' is not defined

# %%
#Displaying maximum and minimum dewpoint and drybulb temperatures.
print('Maximum dew-point temperature = %f'%(Tdp_10m_max))
print('Minimum dew-point temperature = %f'%(Tdp_10m_min))
print('Maximum dry-bulb temperature = %f'%(TaC_10m_max))
print('Minimum dry-bulb temperature = %f'%(TaC_10m_min))

# %%
#Plot dew-point and dry-bulb over datetime.

fig, ax1 = plt.subplots()
fig.suptitle('Dew-point and Dry-bulb Over Datetime', fontsize=10, fontweight='bold')
x = np.array(datetime_array)
y1 = Tdp_10m
y2 = TaC_10m
ax1.set_xlabel('Datetime')
ax1.plot(x, y1, 'b-')
ax1.set_ylabel('Dew-point Temperature °C', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')
plt.ylim((-8,35))

ax2 = ax1.twinx()

ax2.plot(x, y2, 'r-')
ax2.set_ylabel('Dry-bulb Temperature °C', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.ylim((-8,35))


x_lims = (datetime_array)

# Converting datetime.datetime objects to the correct format for matplotlib to work with.
date_format = mdates.DateFormatter('%Y/%m/%d %H:%M:%S')
x_lims = mdates.date2num(x_lims)
ax1.xaxis_date()

# Using DateFormatter to choose how datetime string will appear.


ax1.xaxis.set_major_formatter(date_format)
fig.autofmt_xdate()  

ax1.annotate('local max', xy=(3, 1), xycoords='data',
                xytext=(0.8, 0.95), textcoords='axes fraction',
                arrowprops=dict(facecolor='black', shrink=0.05),
                horizontalalignment='right', verticalalignment='top')
                

plt.fill_between(x, y1, y2, color='green', alpha='0.5')

plt.show()
